# %%
def readfile(filename):
    file=open(filename,encoding='utf-8')
    text=file.read().split('\n')[:-1]
    return text

# %%
eng_train=readfile("english_train")
# tml_train=readfile("tamil_train")

# eng_val=readfile("english_val")
# tml_val=readfile("tamil_val")

# eng_test=readfile("english_test")
# tml_test=readfile("tamil_test")

#train
list1=[]
first1='<doc sysid="ref" docid="124-cyberpresse" genre="news" origlang="en">'
list1.append(first1)
for i in range(len(eng_train)):
    final1='<seg id="'+str(i+1)+'">'+eng_train[i]+'</seg>'
    list1.append(final1)
last1="</doc>"
list1.append(last1)

# list2=[]
# first2='<doc sysid="ref" docid="124-cyberpresse" genre="news" origlang="ta">'
# list2.append(first2)
# for i in range(len(tml_train)):
#     final2='<seg id="'+str(i+1)+'">'+tml_train[i]+'</seg>'
#     list2.append(final2)
# last2="</doc>"
# list2.append(last2)

# #valid
# list3=[]
# first3='<doc sysid="ref" docid="124-cyberpresse" genre="news" origlang="en">'
# list3.append(first3)
# for i in range(len(eng_val)):
#     final3='<seg id="'+str(i+1)+'">'+eng_val[i]+'</seg>'
#     list3.append(final3)
# last3="</doc>"
# list3.append(last3)

# list4=[]
# first4='<doc sysid="ref" docid="124-cyberpresse" genre="news" origlang="ta">'
# list4.append(first4)
# for i in range(len(tml_val)):
#     final4='<seg id="'+str(i+1)+'">'+tml_val[i]+'</seg>'
#     list4.append(final4)
# last4="</doc>"
# list4.append(last4)

# #test
# list5=[]
# first5='<doc sysid="ref" docid="124-cyberpresse" genre="news" origlang="en">'
# list5.append(first5)
# for i in range(len(eng_test)):
#     final5='<seg id="'+str(i+1)+'">'+eng_test[i]+'</seg>'
#     list5.append(final5)
# last5="</doc>"
# list5.append(last5)

# list6=[]
# first6='<doc sysid="ref" docid="124-cyberpresse" genre="news" origlang="ta">'
# list6.append(first6)
# for i in range(len(tml_test)):
#     final6='<seg id="'+str(i+1)+'">'+tml_test[i]+'</seg>'
#     list6.append(final6)
# last6="</doc>"
# list6.append(last6)

import io
with io.open("english_train", 'w', encoding="utf-8") as f:
    for item in list1:
        f.write("{}\n".format(item))
    
# with io.open("tamil_train", 'w', encoding="utf-8") as f:
#     for item in list2:
#         f.write("{}\n".format(item))

# with io.open("english_val", 'w', encoding="utf-8") as f:
#     for item in list3:
#         f.write("{}\n".format(item))

# with io.open("tamil_val", 'w', encoding="utf-8") as f:
#     for item in list4:
#         f.write("{}\n".format(item))
        
# with io.open("english_test", 'w', encoding="utf-8") as f:
#     for item in list5:
#         f.write("{}\n".format(item))

# with io.open("tami_test", 'w', encoding="utf-8") as f:
#     for item in list6:
#         f.write("{}\n".format(item))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-81d830591645> in <module>
# ----> 1 eng_train=readfile("english_train")
#       2 # tml_train=readfile("tamil_train")
#       3
#       4 # eng_val=readfile("english_val")
#       5 # tml_val=readfile("tamil_val")
#
# <ipython-input-1-7a854568b3f0> in readfile(filename)
#       1 def readfile(filename):
# ----> 2     file=open(filename,encoding='utf-8')
#       3     text=file.read().split('\n')[:-1]
#       4     return text
#
# FileNotFoundError: [Errno 2] No such file or directory: 'english_train'
